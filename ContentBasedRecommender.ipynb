# %% [markdown]
# <a href="https://colab.research.google.com/github/skarot/RecommenderSystem/blob/main/ContentBasedRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recommender System for movie recommendation

# %% [markdown]
# ## Content based recommender
#
# This type of recommender system doesnot depend on user, but is based on the similarity of items. Like on Amazon website 'people also bought', 'often bought together'.

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/content'

# %%
#cd ..
# %cd '/content'
# Out:
# /content

# %%
df_credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
df_movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
#df_movies['genres'].loc[4802:].values[0]

# %%
"""import json
op = json.loads(df_movies['genres'].loc[4802:].values[0])
op[0]['name']
#df_movies['genres'].loc[4802:].values[0]"""
# Out:
# "import json\nop = json.loads(df_movies['genres'].loc[4802:].values[0])\nop[0]['name']\n#df_movies['genres'].loc[4802:].values[0]"

# %% [markdown]
# ### Data Analysis

# %%
df_credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df_movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# ### Merge two df based on movie_id as id

# %% [markdown]
# Rename the column movie_id to id in df_credits dataframe

# %%
#df_credits.rename(inplace = True,columns = {'movie_id':'id'})
df_credits.rename({'movie_id':'id'}, axis = 1,inplace = True)

# %%
df_credits
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %% [markdown]
# Merge

# %%
df = df_movies.merge(df_credits,  on='id')

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Remove unwanted columns

# %%
df = df.drop(['production_countries','status','title_y','title_x','homepage'], axis = 1)

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'tagline',
#        'vote_average', 'vote_count', 'cast', 'crew'],
#       dtype='object')

# %% [markdown]
# ## Vectorization

# %% [markdown]
# ### Remove null

# %%
df['overview'] = df['overview'].fillna('')

# %% [markdown]
# ### Use NLP tfidf to convert the Overview column text into vectors

# %%
df['overview'].head(5)
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tvz = TfidfVectorizer(strip_accents='unicode',analyzer='word',stop_words='english',token_pattern = '\w{1,}',min_df=3,ngram_range=(1,3))

# %%
df_vector = tvz.fit_transform(df['overview'])

# %%
df_vector.shape
# Out:
# (4803, 10417)

# %%
df_vector[0]
# Out:
# <1x10417 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## SigmoidKernel to calculate similarity between each overview with others

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

sig = sigmoid_kernel(df_vector,df_vector)

# %%
sig[1363]
#array([0.76159416, 0.76159416, 0.76159455, ..., 0.76159473, 0.76159461,
#0.76163447])
# Out:
# array([0.76159416, 0.76159451, 0.76159533, ..., 0.76159444, 0.76159444,
#        0.76159473])

# %% [markdown]
# This array of score will have how similar an entry of overview is with others. The first value will be highest as it is similarity of first with utself

# %% [markdown]
# ### Create a reverse mapping of movie indices with title and id

# %%
movie_indices = pd.Series(df.index,index=df['original_title']).drop_duplicates()

# %% [markdown]
# ### Create an enumerated list of sigmoid score

# %%
movie_indices
# Out:
# original_title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4798
# Newlyweds                                   4799
# Signed, Sealed, Delivered                   4800
# Shanghai Calling                            4801
# My Date with Drew                           4802
# Length: 4803, dtype: int64

# %% [markdown]
# This can later be mapped to movie_indices series to get score per title

# %% [markdown]
# ## Custom code, used sigmoid score to get top 10 recommendations

# %%
def get_rec(title,sig = sig):
  movie_index = movie_indices[title]

  sig_array = sig[movie_index]

  sig_score_per_id = list(enumerate(sig_array))

  sig_scores = sorted(sig_score_per_id, key = lambda x:x[1], reverse = True)
  #sig_score_sorted is a list of tuples, where each tuple is (id, title)
  sig_score_sorted = sig_scores[1:11]

  movie_rec_ids = [i[0] for i in sig_score_sorted]

  movie_recs =df['original_title'].iloc[movie_rec_ids]

  return movie_recs

print(get_rec('Spy Kids',sig))
# Out:
# 1302    Spy Kids 2: The Island of Lost Dreams
# 1155                  Spy Kids 3-D: Game Over
# 1769      Spy Kids: All the Time in the World
# 4044                               Go for It!
# 3359                              In Too Deep
# 1631                                 Mr. 3000
# 1825                Jimmy Neutron: Boy Genius
# 339                           The Incredibles
# 3793                     The Velocity of Gary
# 1081                       Revolutionary Road
# Name: original_title, dtype: object

# %%
movie_indices['Spy Kids']
# Out:
# 1363

# %% [markdown]
# ### Checking the get_rec function step by step

# %%
movie_index = movie_indices['Titanic']

# %%
movie_index
# Out:
# 25

# %%
sig_array = sig[movie_index]

# %%
sig_array
# Out:
# array([0.76159416, 0.76159444, 0.76159416, ..., 0.76159439, 0.76159439,
#        0.76159669])

# %%
sig_score_per_id = list(enumerate(sig_array))

# %%
sig_score_per_id
# Out:
# [(0, 0.7615941559557649),
#  (1, 0.7615944442292607),
#  (2, 0.7615941559557649),
#  (3, 0.7615953816484402),
#  (4, 0.7615941559557649),
#  (5, 0.7615952758820054),
#  (6, 0.7615943447088489),
#  (7, 0.7615941559557649),
#  (8, 0.7615948407436888),
#  (9, 0.7615941559557649),
#  (10, 0.76159445866237),
#  (11, 0.7615944550911878),
#  (12, 0.7615949707362111),
#  (13, 0.7615956945872773),
#  (14, 0.7615946748155702),
#  (15, 0.7615948189620042),
#  (16, 0.7615941559557649),
#  (17, 0.7615977450530766),
#  (18, 0.7615945715450686),
#  (19, 0.7615941559557649),
#  (20, 0.7615945072237564),
#  (21, 0.7615941559557649),
#  (22, 0.7615941559557649),
#  (23, 0.7615941559557649),
#  (24, 0.7615965711253341),
#  (25, 0.7616344692549826),
#  (26, 0.7615941559557649),
#  (27, 0.7615941559557649),
#  (28, 0.7615945660971247),
#  (29, 0.7615941559557649),
#  (30, 0.7615941559557649),
#  (31, 0.7615949539745203),
#  (32, 0.7615953771907422),
#  (33, 0.7615941559557649),
# ...

# %%
sig_score_sorted = sorted(sig_score_per_id, key = lambda x:x[1], reverse = True)

# %% [markdown]
# NOTE - When we sort in ascending order the score for the given movie itself is highest

# %%
sig_score_sorted =sig_score_sorted[:11]

# %%
sig_score_sorted
# Out:
# [(25, 0.7616344692549826),
#  (1269, 0.7616027041521651),
#  (2289, 0.7616014679405584),
#  (296, 0.7616007835610765),
#  (2287, 0.7615997570256086),
#  (2143, 0.7615996786903533),
#  (4287, 0.7615992776394515),
#  (171, 0.7615992331671503),
#  (4035, 0.7615990905946002),
#  (4228, 0.7615990834896436),
#  (104, 0.7615988066021125)]

# %%
sig_score_sorted[0][0]
# Out:
# 25

# %%
movie_indices[0]
# Out:
# 0

# %%
movie_rec_ids = [i[0] for i in sig_score_sorted]

# %% [markdown]
# ### Test

# %%
# this line should be included in the cell where the function is declared see output there
#print(get_rec('The Dark Knight Rises',sig))
